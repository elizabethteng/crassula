# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels \
    import RBF, WhiteKernel, RationalQuadratic, ExpSineSquared, ConstantKernel

import os
import pickle
from time import time
from sklearn.decomposition import PCA


import pdspy.modeling as modeling
import pdspy.dust as dust
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import glob

import lhsmdu #github.com/sahilm89

# %%
param_names = ["Tstar","logLstar","logMdisk","logRdisk","h0","logRin",\
          "gamma","beta","logMenv","logRenv","fcav","ksi","logamax","p","incl"]

ranges = [[3000.,5000.], [-1,3.],[-8.,-2.], [0.,3.],[0.01,0.5],[-1.,2.5],[0.0,2.0],\
        [0.5,2.0],[-8.,-2.],[2.5,4.], [0.,1.], [0.5,1.5],[0.,5.],[2.5,4.5],[0.,90.]]

steps=[]
bases=[]
for i in range(len(ranges)):
    steps.append(np.linspace(ranges[i][0],ranges[i][1],11))
    bases.append(steps[i][5])
    
# training set - read in filenames and logspace flux values
with open ('../../grid_metadata/core78.txt', 'rb') as fp:
    core= pickle.load(fp)
with open ('../../grid_metadata/cube78.txt', 'rb') as fp:
    cube = np.array(pickle.load(fp))
with open ('../../grid_metadata/cube78.txt', 'rb') as fp:
    nancube = np.array(pickle.load(fp))
    
# x values (wavelengths) - 500 values, in normal space
with open ('../../grid_metadata/xvals.txt', 'rb') as fp:
    xvals = pickle.load(fp)

# %%
#r=[[3000,5000],[0,3]]
#coords=np.array(lhsmdu.sample(2,100))
#coords=coords*np.array([r[0][1]-r[0][0],r[1][1]-r[1][0]])[:,np.newaxis]
#coords+=np.array([r[0][0],r[1][0]])[:,np.newaxis]

#with open('../grid_metadata/2dgrid_coords.txt', 'wb') as fp:
#    pickle.dump(coords, fp)

#with open ('../grid_metadata/2dgrid_coords.txt', 'rb') as fp:
#    coords = pickle.load(fp)

# %%
r=[ranges[4],ranges[5]]
coords=np.array(lhsmdu.sample(2,100))
coords=coords*np.array([r[0][1]-r[0][0],r[1][1]-r[1][0]])[:,np.newaxis]
coords+=np.array([r[0][0],r[1][0]])[:,np.newaxis]

with open('../../grid_metadata/45_coords.txt', 'wb') as fp:
    pickle.dump(coords, fp)

with open ('../../grid_metadata/45_coords.txt', 'rb') as fp:
    coords = pickle.load(fp)

# %%
plt.scatter(coords[0],coords[1])

# %%
def run_yso_model( Tstar=None, logL_star=None, \
        logM_disk=None, logR_disk=None, h_0=None, logR_in=None, gamma=None, \
        beta=None, logM_env=None, logR_env=None, f_cav=None, ksi=None, \
        loga_max=None, p=None, incl=None):
    
    params = [Tstar,logL_star,logM_disk,logR_disk,h_0,logR_in,\
          gamma,beta,logM_env,logR_env,f_cav,ksi,loga_max,p,incl]

    # Set up the dust properties.

    dust_gen = dust.DustGenerator(dust.__path__[0]+"/data/diana_wice.hdf5")
    ddust = dust_gen(10.**loga_max / 1e4, p)
    env_dust_gen = dust.DustGenerator(dust.__path__[0]+\
            "/data/diana_wice.hdf5")
    edust = env_dust_gen(1.0e-4, 3.5)

    # Calculate alpha correctly.

    alpha = gamma + beta

    # Fix the scale height of the disk.

    h_0 *= (10.**logR_disk)**beta

    # Set up the model.

    model = modeling.YSOModel()
    model.add_star(luminosity=10.**logL_star, temperature=Tstar)
    model.set_spherical_grid(10.**logR_in, 10.**logR_env, 100, 101, 2, \
            code="radmc3d")
    model.add_pringle_disk(mass=10.**logM_disk, rmin=10.**logR_in, \
            rmax=10.**logR_disk, plrho=alpha, h0=h_0, plh=beta, dust=ddust)
    model.add_ulrich_envelope(mass=10.**logM_env, rmin=10.**logR_in, \
            rmax=10.**logR_env, cavpl=ksi, cavrfact=f_cav, dust=edust)
    model.grid.set_wavelength_grid(0.1,1.0e5,500,log=True)
    
    print("finished setting up model, now running thermal simulation")

    # Run the thermal simulation
    model.run_thermal(code="radmc3d", nphot=1e6, \
            modified_random_walk=True, verbose=False, setthreads=20, \
            timelimit=10800)
    
    print("finished running thermal simulation, now running SED")
    t2=time()
    
    # Run the SED.

    model.set_camera_wavelength(np.logspace(-1.,4.,500))
    model.run_sed(name="SED", nphot=1e5, loadlambda=True, incl=incl, \
            pa=0., dpc=140., code="radmc3d", camera_scatsrc_allfreq=True, \
            verbose=False, setthreads=20)
    
    filename=""
    for i in range(len(param_names)):
        filename+=param_names[i]+"_"
        filename+=str(params[i])+"_"
    filename=filename[:-1]
    filename+=".hdf5"
    print("finished running "+filename[0:40]+"... in %0.3fs" % (time() - t2))
    
    # Write out the file.
    model.write_yso("../../grid/grid45/"+filename)

# %%
pars=bases

# %%
for i in range(len(coords[0])):
    t0=time()
    run_yso_model(Tstar=pars[0], logL_star=pars[1], \
            logM_disk=pars[2], logR_disk=pars[3], h_0=coords[0][i], logR_in=coords[1][i], gamma=pars[6], \
            beta=pars[7], logM_env=pars[8], logR_env=pars[9], f_cav=pars[10], ksi=pars[11], \
            loga_max=pars[12], p=pars[13], incl=pars[14])
    print("finished running SED #"+str(i)+" in %0.3fs" % (time() - t0))
# Out:
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 294.177s
# finished running SED #0 in 305.883s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 355.314s
# finished running SED #1 in 369.417s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 296.312s
# finished running SED #2 in 307.738s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 636.427s
# finished running SED #3 in 941.080s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 304.367s
# finished running SED #4 in 316.239s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 469.865s
# finished running SED #5 in 620.050s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 573.676s
# finished running SED #6 in 878.244s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 537.315s
# finished running SED #7 in 837.691s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 198.005s
# finished running SED #8 in 202.755s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 635.179s
# finished running SED #9 in 1665.115s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 205.568s
# finished running SED #10 in 211.546s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 219.867s
# finished running SED #11 in 224.355s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 632.291s
# finished running SED #12 in 671.031s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 413.774s
# finished running SED #13 in 442.094s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 502.618s
# finished running SED #14 in 524.062s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 393.352s
# finished running SED #15 in 418.962s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 208.267s
# finished running SED #16 in 215.070s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 623.497s
# finished running SED #17 in 636.757s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 473.674s
# finished running SED #18 in 540.541s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 549.575s
# finished running SED #19 in 616.736s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 520.559s
# finished running SED #20 in 536.674s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 459.719s
# finished running SED #21 in 482.124s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 411.284s
# finished running SED #22 in 481.673s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 253.668s
# finished running SED #23 in 261.500s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 243.700s
# finished running SED #24 in 252.489s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 223.191s
# finished running SED #25 in 231.270s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 228.569s
# finished running SED #26 in 233.582s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 212.196s
# finished running SED #27 in 219.515s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 502.711s
# finished running SED #28 in 672.126s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 382.870s
# finished running SED #29 in 396.969s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 200.602s
# finished running SED #30 in 205.024s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 457.844s
# finished running SED #31 in 544.755s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 606.674s
# finished running SED #32 in 1185.889s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 438.228s
# finished running SED #33 in 481.481s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 531.055s
# finished running SED #34 in 548.841s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 447.248s
# finished running SED #35 in 498.930s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 206.121s
# finished running SED #36 in 211.395s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 627.688s
# finished running SED #37 in 1002.450s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 527.947s
# finished running SED #38 in 855.267s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 230.623s
# finished running SED #39 in 236.895s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 525.827s
# finished running SED #40 in 815.472s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 267.224s
# finished running SED #41 in 277.174s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 375.068s
# finished running SED #42 in 388.310s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 641.488s
# finished running SED #43 in 708.185s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 250.562s
# finished running SED #44 in 259.626s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 718.829s
# finished running SED #45 in 732.432s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 397.265s
# finished running SED #46 in 411.776s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 553.034s
# finished running SED #47 in 976.512s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 432.343s
# finished running SED #48 in 479.421s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 576.008s
# finished running SED #49 in 778.322s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 361.070s
# finished running SED #50 in 374.963s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 556.563s
# finished running SED #51 in 1064.027s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 489.016s
# finished running SED #52 in 509.005s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 204.938s
# finished running SED #53 in 211.263s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 669.214s
# finished running SED #54 in 684.663s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 222.266s
# finished running SED #55 in 229.039s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 649.844s
# finished running SED #56 in 707.630s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 491.022s
# finished running SED #57 in 515.320s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 568.818s
# finished running SED #58 in 713.056s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 562.979s
# finished running SED #59 in 759.115s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 202.923s
# finished running SED #60 in 209.108s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 528.624s
# finished running SED #61 in 553.797s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 215.663s
# finished running SED #62 in 223.448s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 451.330s
# finished running SED #63 in 559.093s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 560.705s
# finished running SED #64 in 593.608s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 506.897s
# finished running SED #65 in 586.769s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 413.485s
# finished running SED #66 in 429.139s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 205.197s
# finished running SED #67 in 210.378s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 601.579s
# finished running SED #68 in 648.895s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 601.371s
# finished running SED #69 in 667.097s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 379.882s
# finished running SED #70 in 392.779s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 205.980s
# finished running SED #71 in 211.727s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 544.498s
# finished running SED #72 in 576.699s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 250.776s
# finished running SED #73 in 259.953s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 222.527s
# finished running SED #74 in 227.584s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 606.247s
# finished running SED #75 in 660.646s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 426.681s
# finished running SED #76 in 474.532s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 438.901s
# finished running SED #77 in 463.466s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 613.124s
# finished running SED #78 in 652.462s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 314.083s
# finished running SED #79 in 325.276s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 547.656s
# finished running SED #80 in 835.683s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 621.727s
# finished running SED #81 in 700.211s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 327.116s
# finished running SED #82 in 339.924s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 226.239s
# finished running SED #83 in 236.409s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 573.520s
# finished running SED #84 in 1130.540s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 616.868s
# finished running SED #85 in 713.272s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 209.049s
# finished running SED #86 in 216.337s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 567.180s
# finished running SED #87 in 591.240s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 238.360s
# finished running SED #88 in 246.732s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 265.111s
# finished running SED #89 in 276.849s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 613.808s
# finished running SED #90 in 748.029s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 203.428s
# finished running SED #91 in 207.942s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 530.363s
# finished running SED #92 in 586.750s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 592.723s
# finished running SED #93 in 1414.337s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 450.959s
# finished running SED #94 in 531.606s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 381.407s
# finished running SED #95 in 402.094s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 457.630s
# finished running SED #96 in 515.960s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 602.833s
# finished running SED #97 in 1397.615s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 623.489s
# finished running SED #98 in 707.183s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 592.266s
# finished running SED #99 in 1697.098s

# %%
r=[ranges[13],ranges[14]]
coords=np.array(lhsmdu.sample(2,100))
coords=coords*np.array([r[0][1]-r[0][0],r[1][1]-r[1][0]])[:,np.newaxis]
coords+=np.array([r[0][0],r[1][0]])[:,np.newaxis]

with open('../../grid_metadata/1314_coords.txt', 'wb') as fp:
    pickle.dump(coords, fp)

with open ('../../grid_metadata/1314_coords.txt', 'rb') as fp:
    coords = pickle.load(fp)

# %%
def run_yso_model( Tstar=None, logL_star=None, \
        logM_disk=None, logR_disk=None, h_0=None, logR_in=None, gamma=None, \
        beta=None, logM_env=None, logR_env=None, f_cav=None, ksi=None, \
        loga_max=None, p=None, incl=None):
    
    params = [Tstar,logL_star,logM_disk,logR_disk,h_0,logR_in,\
          gamma,beta,logM_env,logR_env,f_cav,ksi,loga_max,p,incl]

    # Set up the dust properties.

    dust_gen = dust.DustGenerator(dust.__path__[0]+"/data/diana_wice.hdf5")
    ddust = dust_gen(10.**loga_max / 1e4, p)
    env_dust_gen = dust.DustGenerator(dust.__path__[0]+\
            "/data/diana_wice.hdf5")
    edust = env_dust_gen(1.0e-4, 3.5)

    # Calculate alpha correctly.

    alpha = gamma + beta

    # Fix the scale height of the disk.

    h_0 *= (10.**logR_disk)**beta

    # Set up the model.

    model = modeling.YSOModel()
    model.add_star(luminosity=10.**logL_star, temperature=Tstar)
    model.set_spherical_grid(10.**logR_in, 10.**logR_env, 100, 101, 2, \
            code="radmc3d")
    model.add_pringle_disk(mass=10.**logM_disk, rmin=10.**logR_in, \
            rmax=10.**logR_disk, plrho=alpha, h0=h_0, plh=beta, dust=ddust)
    model.add_ulrich_envelope(mass=10.**logM_env, rmin=10.**logR_in, \
            rmax=10.**logR_env, cavpl=ksi, cavrfact=f_cav, dust=edust)
    model.grid.set_wavelength_grid(0.1,1.0e5,500,log=True)
    
    print("finished setting up model, now running thermal simulation")

    # Run the thermal simulation
    model.run_thermal(code="radmc3d", nphot=1e6, \
            modified_random_walk=True, verbose=False, setthreads=20, \
            timelimit=10800)
    
    print("finished running thermal simulation, now running SED")
    t2=time()
    
    # Run the SED.

    model.set_camera_wavelength(np.logspace(-1.,4.,500))
    model.run_sed(name="SED", nphot=1e5, loadlambda=True, incl=incl, \
            pa=0., dpc=140., code="radmc3d", camera_scatsrc_allfreq=True, \
            verbose=False, setthreads=20)
    
    filename=""
    for i in range(len(param_names)):
        filename+=param_names[i]+"_"
        filename+=str(params[i])+"_"
    filename=filename[:-1]
    filename+=".hdf5"
    print("finished running "+filename[0:40]+"... in %0.3fs" % (time() - t2))
    
    # Write out the file.
    model.write_yso("../../grid/grid1314/"+filename)

# %%
for i in range(len(coords[0])):
    t0=time()
    run_yso_model(Tstar=pars[0], logL_star=pars[1], \
            logM_disk=pars[2], logR_disk=pars[3], h_0=pars[4], logR_in=pars[5], gamma=pars[6], \
            beta=pars[7], logM_env=pars[8], logR_env=pars[9], f_cav=pars[10], ksi=pars[11], \
            loga_max=pars[12], p=coords[0][i], incl=coords[1][i])
    print("finished running SED #"+str(i)+" in %0.3fs" % (time() - t0))
# Out:
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 450.064s
# finished running SED #0 in 469.998s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 559.466s
# finished running SED #1 in 583.791s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 567.182s
# finished running SED #2 in 602.534s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 358.935s
# finished running SED #3 in 447.861s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 348.329s
# finished running SED #4 in 437.256s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 564.066s
# finished running SED #5 in 594.876s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 439.102s
# finished running SED #6 in 504.950s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 545.031s
# finished running SED #7 in 587.515s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 503.772s
# finished running SED #8 in 557.061s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 343.339s
# finished running SED #9 in 434.123s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 473.059s
# finished running SED #10 in 493.438s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 346.401s
# finished running SED #11 in 433.329s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 406.788s
# finished running SED #12 in 483.365s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 558.542s
# finished running SED #13 in 582.580s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 346.863s
# finished running SED #14 in 435.055s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 429.729s
# finished running SED #15 in 452.321s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 554.531s
# finished running SED #16 in 586.997s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 420.773s
# finished running SED #17 in 438.840s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 576.494s
# finished running SED #18 in 603.517s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 575.269s
# finished running SED #19 in 611.986s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 407.919s
# finished running SED #20 in 426.143s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 582.936s
# finished running SED #21 in 612.789s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 553.037s
# finished running SED #22 in 576.317s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 468.318s
# finished running SED #23 in 487.541s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 473.034s
# finished running SED #24 in 493.531s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 555.862s
# finished running SED #25 in 593.228s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 599.853s
# finished running SED #26 in 628.719s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 560.506s
# finished running SED #27 in 588.974s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 553.769s
# finished running SED #28 in 588.395s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 565.768s
# finished running SED #29 in 609.108s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 308.231s
# finished running SED #30 in 402.366s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 601.910s
# finished running SED #31 in 628.507s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 347.616s
# finished running SED #32 in 437.494s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 569.553s
# finished running SED #33 in 592.323s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 418.839s
# finished running SED #34 in 437.947s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 519.054s
# finished running SED #35 in 541.524s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 402.389s
# finished running SED #36 in 479.707s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 331.848s
# finished running SED #37 in 425.475s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 508.894s
# finished running SED #38 in 559.023s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 560.519s
# finished running SED #39 in 590.028s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 568.752s
# finished running SED #40 in 607.934s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 479.712s
# finished running SED #41 in 541.792s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 344.873s
# finished running SED #42 in 432.773s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 393.680s
# finished running SED #43 in 474.012s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 389.043s
# finished running SED #44 in 466.649s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 418.605s
# finished running SED #45 in 436.378s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 378.866s
# finished running SED #46 in 461.517s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 527.685s
# finished running SED #47 in 576.885s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4000.0_logLstar_1.0_logMdisk_-5.0_... in 489.341s
# finished running SED #48 in 511.792s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
