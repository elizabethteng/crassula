# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels \
    import RBF, WhiteKernel, RationalQuadratic, ExpSineSquared, ConstantKernel

import os
import pickle
from time import time
from sklearn.decomposition import PCA


import pdspy.modeling as modeling
import pdspy.dust as dust
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import glob

import lhsmdu #github.com/sahilm89

# %%
param_names = ["Tstar","logLstar","logMdisk","logRdisk","h0","logRin",\
          "gamma","beta","logMenv","logRenv","fcav","ksi","logamax","p","incl"]

ranges = [[3000.,5000.], [-1,3.],[-8.,-2.], [0.,3.],[0.01,0.5],[-1.,2.5],[0.0,2.0],\
        [0.5,2.0],[-8.,-2.],[2.5,4.], [0.,1.], [0.5,1.5],[0.,5.],[2.5,4.5],[0.,90.]]

steps=[]
bases=[]
for i in range(len(ranges)):
    steps.append(np.linspace(ranges[i][0],ranges[i][1],11))
    bases.append(steps[i][5])
    
# training set - read in filenames and logspace flux values
with open ('../grid_metadata/core78.txt', 'rb') as fp:
    core= pickle.load(fp)
with open ('../grid_metadata/cube78.txt', 'rb') as fp:
    cube = np.array(pickle.load(fp))
with open ('../grid_metadata/cube78.txt', 'rb') as fp:
    nancube = np.array(pickle.load(fp))
    
# x values (wavelengths) - 500 values, in normal space
with open ('../grid_metadata/xvals.txt', 'rb') as fp:
    xvals = pickle.load(fp)

# %%
#r=[[3000,5000],[0,3]]
#coords=np.array(lhsmdu.sample(2,100))
#coords=coords*np.array([r[0][1]-r[0][0],r[1][1]-r[1][0]])[:,np.newaxis]
#coords+=np.array([r[0][0],r[1][0]])[:,np.newaxis]

#with open('../grid_metadata/2dgrid_coords.txt', 'wb') as fp:
#    pickle.dump(coords, fp)

#with open ('../grid_metadata/2dgrid_coords.txt', 'rb') as fp:
#    coords = pickle.load(fp)

# %%
r=[ranges[2],ranges[3]]
coords=np.array(lhsmdu.sample(2,100))
coords=coords*np.array([r[0][1]-r[0][0],r[1][1]-r[1][0]])[:,np.newaxis]
coords+=np.array([r[0][0],r[1][0]])[:,np.newaxis]

with open('../grid_metadata/23_coords.txt', 'wb') as fp:
    pickle.dump(coords, fp)

with open ('../grid_metadata/23_coords.txt', 'rb') as fp:
    coords = pickle.load(fp)

# %%
plt.scatter(coords[0],coords[1])

# %%
def run_yso_model( Tstar=None, logL_star=None, \
        logM_disk=None, logR_disk=None, h_0=None, logR_in=None, gamma=None, \
        beta=None, logM_env=None, logR_env=None, f_cav=None, ksi=None, \
        loga_max=None, p=None, incl=None):
    
    params = [Tstar,logL_star,logM_disk,logR_disk,h_0,logR_in,\
          gamma,beta,logM_env,logR_env,f_cav,ksi,loga_max,p,incl]

    # Set up the dust properties.

    dust_gen = dust.DustGenerator(dust.__path__[0]+"/data/diana_wice.hdf5")
    ddust = dust_gen(10.**loga_max / 1e4, p)
    env_dust_gen = dust.DustGenerator(dust.__path__[0]+\
            "/data/diana_wice.hdf5")
    edust = env_dust_gen(1.0e-4, 3.5)

    # Calculate alpha correctly.

    alpha = gamma + beta

    # Fix the scale height of the disk.

    h_0 *= (10.**logR_disk)**beta

    # Set up the model.

    model = modeling.YSOModel()
    model.add_star(luminosity=10.**logL_star, temperature=Tstar)
    model.set_spherical_grid(10.**logR_in, 10.**logR_env, 100, 101, 2, \
            code="radmc3d")
    model.add_pringle_disk(mass=10.**logM_disk, rmin=10.**logR_in, \
            rmax=10.**logR_disk, plrho=alpha, h0=h_0, plh=beta, dust=ddust)
    model.add_ulrich_envelope(mass=10.**logM_env, rmin=10.**logR_in, \
            rmax=10.**logR_env, cavpl=ksi, cavrfact=f_cav, dust=edust)
    model.grid.set_wavelength_grid(0.1,1.0e5,500,log=True)
    
    print("finished setting up model, now running thermal simulation")

    # Run the thermal simulation
    model.run_thermal(code="radmc3d", nphot=1e6, \
            modified_random_walk=True, verbose=False, setthreads=20, \
            timelimit=10800)
    
    print("finished running thermal simulation, now running SED")
    t2=time()
    
    # Run the SED.

    model.set_camera_wavelength(np.logspace(-1.,4.,500))
    model.run_sed(name="SED", nphot=1e5, loadlambda=True, incl=incl, \
            pa=0., dpc=140., code="radmc3d", camera_scatsrc_allfreq=True, \
            verbose=False, setthreads=20)
    
    filename=""
    for i in range(len(param_names)):
        filename+=param_names[i]+"_"
        filename+=str(params[i])+"_"
    filename=filename[:-1]
    filename+=".hdf5"
    print("finished running "+filename[0:40]+"... in %0.3fs" % (time() - t2))
    
    # Write out the file.
    model.write_yso("../grid/grid06/"+filename)

# %%
pars=bases

# %%
for i in range(len(coords[0])):
    t0=time()
    run_yso_model(Tstar=pars[0], logL_star=pars[1], \
            logM_disk=coords[0][i], logR_disk=coords[1][i], h_0=pars[4], logR_in=pars[5], gamma=pars[6], \
            beta=pars[7], logM_env=pars[8], logR_env=pars[9], f_cav=pars[10], ksi=pars[11], \
            loga_max=pars[12], p=pars[13], incl=pars[14])
    print("finished running SED #"+str(i)+" in %0.3fs" % (time() - t0))
# Out:
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_3243.7026585767726_logLstar_1.0_lo... in 472.036s
# finished running SED #0 in 513.133s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_3510.8380189475674_logLstar_1.0_lo... in 480.282s
# finished running SED #1 in 520.019s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_3877.458916717528_logLstar_1.0_log... in 464.125s
# finished running SED #2 in 502.309s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4794.644497728192_logLstar_1.0_log... in 490.166s
# finished running SED #3 in 526.292s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4876.131222957229_logLstar_1.0_log... in 467.724s
# finished running SED #4 in 506.324s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_3773.1756673342143_logLstar_1.0_lo... in 512.417s
# finished running SED #5 in 544.993s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4225.744779833081_logLstar_1.0_log... in 521.153s
# finished running SED #69 in 560.436s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4085.9261624091196_logLstar_1.0_lo... in 464.874s
# finished running SED #70 in 503.605s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_3344.672155020998_logLstar_1.0_log... in 407.089s
# finished running SED #71 in 429.665s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4240.841863792727_logLstar_1.0_log... in 467.925s
# finished running SED #72 in 507.461s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_3300.3574786946683_logLstar_1.0_lo... in 456.140s
# finished running SED #73 in 493.778s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_3019.754447794721_logLstar_1.0_log... in 392.430s
# finished running SED #74 in 412.192s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4448.555462674717_logLstar_1.0_log... in 475.330s
# finished running SED #75 in 514.711s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_3367.6865329431935_logLstar_1.0_lo... in 476.505s
# finished running SED #76 in 513.714s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_3213.5929456538615_logLstar_1.0_lo... in 492.047s
# finished running SED #77 in 525.390s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4504.365077757301_logLstar_1.0_log... in 484.318s
# finished running SED #78 in 524.044s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4678.999223679004_logLstar_1.0_log... in 448.155s
# finished running SED #79 in 487.386s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4115.726900288311_logLstar_1.0_log... in 498.297s
# finished running SED #80 in 533.682s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4461.7882200462445_logLstar_1.0_lo... in 478.475s
# finished running SED #81 in 517.205s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_3108.3516155156985_logLstar_1.0_lo... in 496.286s
# finished running SED #82 in 536.232s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4077.582366151243_logLstar_1.0_log... in 462.021s
# finished running SED #83 in 496.300s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4418.8946404458275_logLstar_1.0_lo... in 504.430s
# finished running SED #84 in 537.603s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4389.348030224997_logLstar_1.0_log... in 479.824s
# finished running SED #85 in 518.249s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_3272.268227784214_logLstar_1.0_log... in 456.804s
# finished running SED #86 in 489.624s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4703.340678921842_logLstar_1.0_log... in 497.625s
# finished running SED #87 in 537.309s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_3479.8233725227396_logLstar_1.0_lo... in 466.700s
# finished running SED #88 in 501.971s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4584.633434027669_logLstar_1.0_log... in 464.556s
# finished running SED #89 in 501.192s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4638.854635482703_logLstar_1.0_log... in 487.532s
# finished running SED #90 in 525.713s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_3832.9929329798474_logLstar_1.0_lo... in 214.933s
# finished running SED #91 in 223.578s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_3792.154735897577_logLstar_1.0_log... in 477.139s
# finished running SED #92 in 515.852s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4650.25377022033_logLstar_1.0_logM... in 500.575s
# finished running SED #93 in 533.117s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_3564.613396234355_logLstar_1.0_log... in 486.653s
# finished running SED #94 in 519.079s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_3163.5305606401103_logLstar_1.0_lo... in 479.327s
# finished running SED #95 in 517.499s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_3544.4097241814034_logLstar_1.0_lo... in 495.270s
# finished running SED #96 in 532.896s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4723.728765242885_logLstar_1.0_log... in 508.403s
# finished running SED #97 in 539.769s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4495.5916894713355_logLstar_1.0_lo... in 493.624s
# finished running SED #98 in 532.479s
# finished setting up model, now running thermal simulation
# finished running thermal simulation, now running SED
# finished running Tstar_4907.0025051833345_logLstar_1.0_lo... in 508.272s
# finished running SED #99 in 540.136s
